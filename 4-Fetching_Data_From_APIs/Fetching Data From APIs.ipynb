# %%
import pandas as pd
import requests

# %%
respones = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=fbb29ad95f6fbdef8a8c747af0dc7bc7&language=en-US&page=1')

# %%
data = pd.DataFrame(respones.json()['results'])[['id','title','overview','popularity','release_date','vote_count','vote_average']]

# %%
data.head()
# Out:
#        id                        title  \
# 0     238                The Godfather
# 1     278     The Shawshank Redemption
# 2  772071             Cuando Sea Joven
# 3     240        The Godfather Part II
# 4   19404  Dilwale Dulhania Le Jayenge
#
#                                             overview  popularity release_date  \
# 0  Spanning the years 1945 to 1955, a chronicle o...      92.370   1972-03-14
# 1  Framed in the 1940s for the double murder of h...      68.236   1994-09-23
# 2  70-year-old Malena gets a second chance at lif...      33.702   2022-09-14
# 3  In the continuing saga of the Corleone crime f...      45.148   1974-12-20
# 4  Raj is a rich, carefree, happy-go-lucky second...      26.440   1995-10-19
#
#    vote_count  vote_average
# 0       17900           8.7
# 1       23750           8.7
# 2         225           8.6
# 3       10814           8.6
# 4        4127           8.6

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    respones = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=fbb29ad95f6fbdef8a8c747af0dc7bc7&language=en-US&page={}'.format(i))
    temp_df  = pd.DataFrame(respones.json()['results'])[['id','title','overview','popularity','release_date','vote_count','vote_average']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\Mrunmay\AppData\Local\Temp\ipykernel_11564\2620418731.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\Mrunmay\AppData\Local\Temp\ipykernel_11564\2620418731.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\Mrunmay\AppData\Local\Temp\ipykernel_11564\2620418731.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\Mrunmay\AppData\Local\Temp\ipykernel_11564\2620418731.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %%
df
# Out:
#           id                                        title  \
# 0        238                                The Godfather
# 1        278                     The Shawshank Redemption
# 2     772071                             Cuando Sea Joven
# 3        240                        The Godfather Part II
# 4      19404                  Dilwale Dulhania Le Jayenge
# ...      ...                                          ...
# 8555  257091                                     Get Hard
# 8556  188161            A Million Ways to Die in the West
# 8557   48340                                      Sanctum
# 8558  555974                           Brahms: The Boy II
# 8559   13654  101 Dalmatians II: Patch's London Adventure
#
#                                                overview  popularity  \
# 0     Spanning the years 1945 to 1955, a chronicle o...      92.370
# 1     Framed in the 1940s for the double murder of h...      68.236
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')

# %% [markdown]
# go to rapid api for more free api links
